# %%
from vibrational_mode import *

# %% [markdown]
# # -Reading the OUTCAR file

# %% [markdown]
# read_vibrational_modes reads an outcar file and returns a dataframe of the modes, frequencies and frequency types. The file choosen is for methane relaxation. The Nans and Nones are empty spaces.

# %%
read_vibrational_modes("OUTCAR-1")
# Out:
#     index         x         y         z  frequency frequency_type
# 0       5       NaN       NaN       NaN        NaN           None
# 1       0       NaN       NaN       NaN        NaN           None
# 2       C  2.385300  1.358000  7.613286  93.580887              f
# 3       H  1.708176  1.969449  8.159874  93.580887              f
# 4       H  2.556551  0.531415  8.139864  93.580887              f
# 5       H  2.579116  1.486096  7.254812  93.580887              f
# 6       H  4.105244  2.397554  8.408642  93.580887              f
# 7       5       NaN       NaN       NaN        NaN           None
# 8       1       NaN       NaN       NaN        NaN           None
# 9       C  2.484785  1.424711  7.709505  93.580887              f
# 10      H  1.696611  1.982964  8.168058  93.580887              f
# 11      H  2.564301  0.495573  8.157400  93.580887              f
# 12      H  2.588134  1.493068  6.982234  93.580887              f
# 13      H  3.793954  2.203944  8.283966  93.580887              f
# 14      5       NaN       NaN       NaN        NaN           None
# 15      2       NaN       NaN       NaN        NaN           None
# 16      C  2.584270  1.491422  7.805723  93.580887              f
# 17      H  1.685046  1.996479  8.176242  93.580887              f
# 18      H  2.572051  0.459731  8.174937  93.580887              f
# 19      H  2.597151  1.500041  6.709657  93.580887              f
# 20      H  3.482663  2.010335  8.159290  93.580887              f
# 21      5       NaN       NaN       NaN        NaN           None
# 22      3       NaN       NaN       NaN        NaN           None
# 23      C  2.683755  1.558133  7.901942  93.580887              f
# 24      H  1.673481  2.009994  8.184426  93.580887              f
# 25      H  2.579801  0.423889  8.192474  93.580887              f
# 26      H  2.606169  1.507014  6.437080  93.580887              f
# 27      H  3.171372  1.816725  8.034614  93.580887              f
# 28      5       NaN       NaN       NaN        NaN           None
# 29      4       NaN       NaN       NaN        NaN           None
# ..    ...       ...       ...       ...        ...            ...
# 495     H  2.998783  1.710634  6.506141  52.451836            f/i
# 496     H  3.834291  1.927192  7.822096  52.451836            f/i
# 497     5       NaN       NaN       NaN        NaN           None
# 498    71       NaN       NaN       NaN        NaN           None
# 499     C  2.583569  1.526900  7.775579  52.451836            f/i
# 500     H  1.841595  2.155868  8.048381  52.451836            f/i
# 501     H  2.739960  0.506088  8.006426  52.451836            f/i
# 502     H  2.797967  1.605337  6.607899  52.451836            f/i
# 503     H  3.658477  1.968763  7.990693  52.451836            f/i
# 504     5       NaN       NaN       NaN        NaN           None
# 505    72       NaN       NaN       NaN        NaN           None
# 506     C  2.584270  1.491422  7.805723  52.451836            f/i
# 507     H  1.685046  1.996479  8.176242  52.451836            f/i
# 508     H  2.572051  0.459731  8.174937  52.451836            f/i
# 509     H  2.597151  1.500041  6.709657  52.451836            f/i
# 510     H  3.482663  2.010335  8.159290  52.451836            f/i
# 511     5       NaN       NaN       NaN        NaN           None
# 512    73       NaN       NaN       NaN        NaN           None
# 513     C  2.584971  1.455944  7.835867  52.451836            f/i
# 514     H  1.528498  1.837089  8.304104  52.451836            f/i
# 515     H  2.404142  0.413374  8.343448  52.451836            f/i
# 516     H  2.396335  1.394745  6.811415  52.451836            f/i
# 517     H  3.306849  2.051906  8.327887  52.451836            f/i
# 518     5       NaN       NaN       NaN        NaN           None
# 519    74       NaN       NaN       NaN        NaN           None
# 520     C  2.585671  1.420465  7.866012  52.451836            f/i
# 521     H  1.371949  1.677700  8.431965  52.451836            f/i
# 522     H  2.236233  0.367017  8.511959  52.451836            f/i
# 523     H  2.195519  1.289448  6.913173  52.451836            f/i
# 524     H  3.131035  2.093478  8.496484  52.451836            f/i
#
# [525 rows x 6 columns]

# %% [markdown]
# # -get_vibrational_frequency

# %% [markdown]
# get_vibrational_frequency return the vibrational frequencies. This function also allows you specify the kind of frequency whether, imaginary "imag" or non-imaginary "non_imag". kind: "all","imag","non-imag".

# %% [markdown]
# ## all

# %%
get_vibrational_frequency("OUTCAR-1",kind='all')
# Out:
# [93.580887,
#  91.668141,
#  89.596646,
#  83.627951,
#  58.871365,
#  45.775104,
#  41.745686,
#  39.40067,
#  29.821097,
#  6.334797,
#  2.817078,
#  1.833137,
#  3.076182,
#  4.682696,
#  52.451836]

# %% [markdown]
# ## non-imaginary frequencies

# %%
get_vibrational_frequency("OUTCAR-1",kind='non_imag')
# Out:
# array([93.580887, 91.668141, 89.596646, 83.627951, 58.871365, 45.775104,
#        41.745686, 39.40067 , 29.821097,  6.334797,  2.817078])

# %% [markdown]
# ## Imaginary frequencies

# %%
get_vibrational_frequency("OUTCAR-1",kind='imag')
# Out:
# array([ 1.833137,  3.076182,  4.682696, 52.451836])

# %% [markdown]
# # -Export the vibratioanl modes to a .xyz file

# %%
write_xyz("OUTCAR-1",output_file_name= 'Methane')

# %% [markdown]
# # -View Vibrational modes in a movie

# %% [markdown]
# This function allows you to view the modes in a movie. It also allows you to specify the particular modes you want to view.

# %% [markdown]
# ## all

# %%
view_vibrational_modes("OUTCAR-1",frequency_index="all")

# %% [markdown]
# ## specify the index of the one you want to view in a list

# %%
view_vibrational_modes("OUTCAR-1",frequency_index=[3,5,16,7,21])

# %%
#####
